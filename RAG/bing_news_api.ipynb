# %%
import requests
import json

subscription_key = "01d3ada42b5744ca8f17c47a83fef1e1"
search_term = "Microsoft"
end_point = "https://api.bing.microsoft.com/"
url = end_point + "v7.0/custom/images/search?" + "q=" + search_term + "&customconfig=" + "1"

headers = {"Ocp-Apim-Subscription-Key" : subscription_key}
params  = {"q": search_term, "textDecorations": True, "textFormat": "HTML"}

response = requests.get(url, headers=headers, params=params)
response.raise_for_status()
search_results = json.dumps(response.json())

descriptions = [article["description"] for article in search_results["value"]]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-35-861be803f446> in <cell line: 13>()
#      11
#      12 response = requests.get(url, headers=headers, params=params)
# ---> 13 response.raise_for_status()
#      14 search_results = json.dumps(response.json())
#      15
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 404 Client Error: OperationNotFound for url: https://api.bing.microsoft.com/v7.0/custom/images/search?q=Microsoft&customconfig=1&q=Microsoft&textDecorations=True&textFormat=HTML

# %%
from IPython.display import HTML
rows = "\n".join(["<tr><td>{0}</td></tr>".format(desc)
                  for desc in descriptions])
HTML("<table>"+rows+"</table>")
